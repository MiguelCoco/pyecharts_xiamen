# %%
from pyecharts import Map,Liquid

# %%
#厦门市调查人口分布图
value = [274,848,495,1247,346,127]
attr = ['海沧区','湖里区','集美区','思明区','同安区','翔安区']
map = Map("厦门市调查人口分布图", width=1200, height=600)
map.add("", attr, value, maptype='厦门',is_label_show=True,label_text_color="#000",is_visualmap=True, 
        visual_text_color='#000',visual_range=[0,1300],)
map
# Out:
# <script>
#     require.config({
#          paths:{
#            'echarts': '/nbextensions/echarts/echarts.min', 'sha4_men2': '/nbextensions/echarts-china-cities-js/fu2_jian4_sha4_men2'
#          }
#     });
# </script>
# <div id="153740f51d3144dfa5ee23eb5117dae5" style="width:1200px; height:600px;"></div>
#
# <script>
#     require([ 'echarts', 'sha4_men2' ],function(ec){
# 	var myChart = ec.init(document.getElementById('153740f51d3144dfa5ee23eb5117dae5'));
# var option =  {
#     "title": [
#         {
#             "text": "\u53a6\u95e8\u5e02\u8c03\u67e5\u4eba\u53e3\u5206\u5e03\u56fe",
#             "subtext": "",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "color": "#000",
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "color": "#aaa",
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             }
#         }
#     },
#     "series_id": 4490324,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "formatter": null,
#         "textStyle": {
#             "color": "#fff",
#             "fontSize": 14
#         }
#     },
#     "series": [
#         {
#             "type": "map",
#             "name": "",
#             "symbol": "circle",
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "top",
#                     "textStyle": {
#                         "color": "#000",
#                         "fontSize": 12
#                     },
#                     "formatter": null
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "position": null,
#                     "textStyle": {
#                         "color": "#fff",
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "mapType": "\u53a6\u95e8",
#             "data": [
#                 {
#                     "name": "\u6d77\u6ca7\u533a",
#                     "value": 274
#                 },
#                 {
#                     "name": "\u6e56\u91cc\u533a",
#                     "value": 848
#                 },
#                 {
#                     "name": "\u96c6\u7f8e\u533a",
#                     "value": 495
#                 },
#                 {
#                     "name": "\u601d\u660e\u533a",
#                     "value": 1247
#                 },
#                 {
#                     "name": "\u540c\u5b89\u533a",
#                     "value": 346
#                 },
#                 {
#                     "name": "\u7fd4\u5b89\u533a",
#                     "value": 127
#                 }
#             ],
#             "roam": true,
#             "showLegendSymbol": true
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12,
#                 "color": "#333"
#             }
#         }
#     ],
#     "backgroundColor": "#fff",
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ],
#     "visualMap": {
#         "type": "continuous",
#         "min": 0,
#         "max": 1300,
#         "text": [
#             "high",
#             "low"
#         ],
#         "textStyle": {
#             "color": "#000"
#         },
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "calculable": true,
#         "splitNumber": 5,
#         "dimension": null,
#         "orient": "vertical",
#         "left": "left",
#         "top": "bottom",
#         "showLabel": true
#     }
# };
# myChart.setOption(option);
#
#     });
# </script>

# %%
#厦门市男性占比水球图
sex_ratio = Liquid("男性占比")
sex_ratio.add("男性占比", [0.49],shape='pin')
sex_ratio
# Out:
# <script>
#     require.config({
#          paths:{
#            'echarts': '/nbextensions/echarts/echarts.min', 'liquidfill': '/nbextensions/echarts/echarts-liquidfill.min'
#          }
#     });
# </script>
# <div id="077dc495e4f44a42a8abfafac2e8fd0e" style="width:800px; height:400px;"></div>
#
# <script>
#     require([ 'echarts', 'liquidfill' ],function(ec){
# 	var myChart = ec.init(document.getElementById('077dc495e4f44a42a8abfafac2e8fd0e'));
# var option =  {
#     "title": [
#         {
#             "text": "\u7537\u6027\u5360\u6bd4",
#             "subtext": "",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "color": "#000",
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "color": "#aaa",
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             }
#         }
#     },
#     "series_id": 5431563,
#     "tooltip": {},
#     "series": [
#         {
#             "type": "liquidFill",
#             "name": "\u7537\u6027\u5360\u6bd4",
#             "data": [
#                 0.49
#             ],
#             "waveAnimation": true,
#             "animationDuration": 2000,
#             "animationDurationUpdate": 1000,
#             "color": [
#                 "#294D99",
#                 "#156ACF",
#                 "#1598ED",
#                 "#45BDFF"
#             ],
#             "shape": "pin",
#             "outline": {
#                 "show": true
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": []
#         }
#     ],
#     "backgroundColor": "#fff"
# };
# myChart.setOption(option);
#
#     });
# </script>

# %%
#厦门市女性占比水球图
sex_ratio = Liquid("女性占比")
sex_ratio.add("女性占比", [0.51],shape='pin')
sex_ratio
# Out:
# <script>
#     require.config({
#          paths:{
#            'echarts': '/nbextensions/echarts/echarts.min', 'liquidfill': '/nbextensions/echarts/echarts-liquidfill.min'
#          }
#     });
# </script>
# <div id="77075416ee8348cda2d385718c748693" style="width:800px; height:400px;"></div>
#
# <script>
#     require([ 'echarts', 'liquidfill' ],function(ec){
# 	var myChart = ec.init(document.getElementById('77075416ee8348cda2d385718c748693'));
# var option =  {
#     "title": [
#         {
#             "text": "\u5973\u6027\u5360\u6bd4",
#             "subtext": "",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "color": "#000",
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "color": "#aaa",
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             }
#         }
#     },
#     "series_id": 3481968,
#     "tooltip": {},
#     "series": [
#         {
#             "type": "liquidFill",
#             "name": "\u5973\u6027\u5360\u6bd4",
#             "data": [
#                 0.51
#             ],
#             "waveAnimation": true,
#             "animationDuration": 2000,
#             "animationDurationUpdate": 1000,
#             "color": [
#                 "#294D99",
#                 "#156ACF",
#                 "#1598ED",
#                 "#45BDFF"
#             ],
#             "shape": "pin",
#             "outline": {
#                 "show": true
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": []
#         }
#     ],
#     "backgroundColor": "#fff"
# };
# myChart.setOption(option);
#
#     });
# </script>

# %%
from pyecharts import Polar

radius = ['海沧区','湖里区','集美区','思明区','同安区','翔安区']
polar = Polar("厦门市各行政区拥有车辆分布", width=1200, height=600)
polar.add("私人小汽车", [169,375,299,518,222,72], radius_data=radius,
          type='barAngle', is_stack=True)
polar.add("摩托车", [85,4,301,7,289,114], radius_data=radius,
          type='barAngle', is_stack=True)
polar.add("电动车", [117,198,134,126,127,20], radius_data=radius,
          type='barAngle', is_stack=True)
polar.add("其他", [2,3,5,3,9,1], radius_data=radius,
          type='barAngle', is_stack=True)
polar
# Out:
# <script>
#     require.config({
#          paths:{
#            'echarts': '/nbextensions/echarts/echarts.min'
#          }
#     });
# </script>
# <div id="05112ea14aaf41bb8cb839ed85ca2fb7" style="width:1200px; height:600px;"></div>
#
# <script>
#     require([ 'echarts' ],function(ec){
# 	var myChart = ec.init(document.getElementById('05112ea14aaf41bb8cb839ed85ca2fb7'));
# var option =  {
#     "title": [
#         {
#             "text": "\u53a6\u95e8\u5e02\u5404\u884c\u653f\u533a\u62e5\u6709\u8f66\u8f86\u5206\u5e03",
#             "subtext": "",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "color": "#000",
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "color": "#aaa",
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             }
#         }
#     },
#     "series_id": 7759584,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "formatter": null,
#         "textStyle": {
#             "color": "#fff",
#             "fontSize": 14
#         }
#     },
#     "series": [
#         {
#             "type": "bar",
#             "stack": "stack",
#             "name": "\u79c1\u4eba\u5c0f\u6c7d\u8f66",
#             "coordinateSystem": "polar",
#             "data": [
#                 169,
#                 375,
#                 299,
#                 518,
#                 222,
#                 72
#             ]
#         },
#         {
#             "type": "bar",
#             "stack": "stack",
#             "name": "\u6469\u6258\u8f66",
#             "coordinateSystem": "polar",
#             "data": [
#                 85,
#                 4,
#                 301,
#                 7,
#                 289,
#                 114
#             ]
#         },
#         {
#             "type": "bar",
#             "stack": "stack",
#             "name": "\u7535\u52a8\u8f66",
#             "coordinateSystem": "polar",
#             "data": [
#                 117,
#                 198,
#                 134,
#                 126,
#                 127,
#                 20
#             ]
#         },
#         {
#             "type": "bar",
#             "stack": "stack",
#             "name": "\u5176\u4ed6",
#             "coordinateSystem": "polar",
#             "data": [
#                 2,
#                 3,
#                 5,
#                 3,
#                 9,
#                 1
#             ]
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u79c1\u4eba\u5c0f\u6c7d\u8f66",
#                 "\u6469\u6258\u8f66",
#                 "\u7535\u52a8\u8f66",
#                 "\u5176\u4ed6"
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12,
#                 "color": "#333"
#             }
#         }
#     ],
#     "backgroundColor": "#fff",
#     "radiusAxis": {
#         "show": true
#     },
#     "angleAxis": {
#         "show": true,
#         "type": "category",
#         "data": [
#             "\u6d77\u6ca7\u533a",
#             "\u6e56\u91cc\u533a",
#             "\u96c6\u7f8e\u533a",
#             "\u601d\u660e\u533a",
#             "\u540c\u5b89\u533a",
#             "\u7fd4\u5b89\u533a"
#         ],
#         "z": 50,
#         "startAngle": 90,
#         "splitLine": {
#             "show": true,
#             "lineStyle": {
#                 "normal": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid",
#                     "color": null
#                 }
#             }
#         }
#     },
#     "polar": {},
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ]
# };
# myChart.setOption(option);
#
#     });
# </script>

# %%
from pyecharts import Scatter3D

import random
data = [
    [random.randint(0, 100),
    random.randint(0, 100),
    random.randint(0, 100)] for _ in range(80)
]
range_color = [
    '#313695', '#4575b4', '#74add1', '#abd9e9', '#e0f3f8', '#ffffbf',
    '#fee090', '#fdae61', '#f46d43', '#d73027', '#a50026']
scatter3D = Scatter3D("3D 散点图示例", width=1200, height=600)
scatter3D.add("", data, is_visualmap=True, visual_range_color=range_color)
scatter3D
# Out:
# <script>
#     require.config({
#          paths:{
#            'echarts': '/nbextensions/echarts/echarts.min', 'echartsgl': '/nbextensions/echarts/echarts-gl.min'
#          }
#     });
# </script>
# <div id="57d6292899d24ecf9ced40912766eadf" style="width:1200px; height:600px;"></div>
#
# <script>
#     require([ 'echarts', 'echartsgl' ],function(ec){
# 	var myChart = ec.init(document.getElementById('57d6292899d24ecf9ced40912766eadf'));
# var option =  {
#     "title": [
#         {
#             "text": "3D \u6563\u70b9\u56fe\u793a\u4f8b",
#             "subtext": "",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "color": "#000",
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "color": "#aaa",
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             }
#         }
#     },
#     "series_id": 4779120,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "formatter": null,
#         "textStyle": {
#             "color": "#fff",
#             "fontSize": 14
#         }
#     },
#     "series": [
#         {
#             "type": "scatter3D",
#             "name": "",
#             "data": [
#                 [
#                     73,
#                     16,
#                     59
#                 ],
#                 [
#                     65,
#                     47,
#                     100
#                 ],
#                 [
#                     3,
#                     5,
#                     24
#                 ],
#                 [
#                     9,
#                     44,
#                     73
#                 ],
#                 [
#                     56,
#                     61,
#                     9
#                 ],
#                 [
#                     70,
#                     13,
#                     44
#                 ],
#                 [
#                     66,
#                     75,
#                     18
#                 ],
#                 [
#                     47,
#                     100,
#                     45
#                 ],
#                 [
#                     11,
#                     73,
#                     9
#                 ],
#                 [
#                     58,
#                     36,
#                     38
#                 ],
#                 [
#                     74,
#                     36,
#                     67
#                 ],
#                 [
#                     28,
#                     12,
#                     50
#                 ],
#                 [
#                     96,
#                     58,
#                     11
#                 ],
#                 [
#                     25,
#                     81,
#                     3
#                 ],
#                 [
#                     50,
#                     87,
#                     64
#                 ],
#                 [
#                     22,
#                     8,
#                     66
#                 ],
#                 [
#                     84,
#                     30,
#                     3
#                 ],
#                 [
#                     28,
#                     97,
#                     52
#                 ],
#                 [
#                     84,
#                     18,
#                     45
#                 ],
#                 [
#                     19,
#                     64,
#                     74
#                 ],
#                 [
#                     50,
#                     73,
#                     69
#                 ],
#                 [
#                     54,
#                     92,
#                     57
#                 ],
#                 [
#                     23,
#                     12,
#                     6
#                 ],
#                 [
#                     40,
#                     81,
#                     59
#                 ],
#                 [
#                     61,
#                     19,
#                     100
#                 ],
#                 [
#                     49,
#                     100,
#                     17
#                 ],
#                 [
#                     32,
#                     84,
#                     34
#                 ],
#                 [
#                     37,
#                     38,
#                     10
#                 ],
#                 [
#                     41,
#                     38,
#                     81
#                 ],
#                 [
#                     70,
#                     47,
#                     27
#                 ],
#                 [
#                     20,
#                     42,
#                     16
#                 ],
#                 [
#                     22,
#                     55,
#                     46
#                 ],
#                 [
#                     29,
#                     26,
#                     7
#                 ],
#                 [
#                     4,
#                     27,
#                     43
#                 ],
#                 [
#                     95,
#                     7,
#                     75
#                 ],
#                 [
#                     97,
#                     2,
#                     98
#                 ],
#                 [
#                     53,
#                     68,
#                     9
#                 ],
#                 [
#                     60,
#                     32,
#                     76
#                 ],
#                 [
#                     92,
#                     66,
#                     82
#                 ],
#                 [
#                     68,
#                     10,
#                     14
#                 ],
#                 [
#                     89,
#                     17,
#                     16
#                 ],
#                 [
#                     8,
#                     79,
#                     87
#                 ],
#                 [
#                     69,
#                     86,
#                     43
#                 ],
#                 [
#                     59,
#                     92,
#                     46
#                 ],
#                 [
#                     47,
#                     29,
#                     39
#                 ],
#                 [
#                     71,
#                     80,
#                     69
#                 ],
#                 [
#                     8,
#                     23,
#                     68
#                 ],
#                 [
#                     77,
#                     82,
#                     7
#                 ],
#                 [
#                     92,
#                     3,
#                     33
#                 ],
#                 [
#                     67,
#                     48,
#                     96
#                 ],
#                 [
#                     87,
#                     62,
#                     12
#                 ],
#                 [
#                     63,
#                     82,
#                     15
#                 ],
#                 [
#                     32,
#                     100,
#                     42
#                 ],
#                 [
#                     4,
#                     64,
#                     44
#                 ],
#                 [
#                     55,
#                     12,
#                     27
#                 ],
#                 [
#                     54,
#                     83,
#                     29
#                 ],
#                 [
#                     15,
#                     37,
#                     75
#                 ],
#                 [
#                     100,
#                     18,
#                     60
#                 ],
#                 [
#                     27,
#                     47,
#                     14
